# %%
# Libraries
import pandas as pd
from IPython.display import HTML

# %% [markdown]
# # Questions I'm Trying to Answer
# - Overpaying for rarity
# - Who owns the most
# - Biggest winning trades and losing trades

# %%
# Import Sales Data
sales = pd.read_csv("sales_0xBC4CA0EdA7647A8aB7C2061c2E118A18a936f13D_04302022.csv")
sales.head()
# Out:
#                                     transaction_hash  block_number  \
# 0  0xb235f0321b0b50198399ec7f2bb759ef625f85673b4d...      14675897
# 1  0x1cf83a120540049239c62de9aa6cbc42bae7494cdf02...      14675814
# 2  0xf9854d2f02c074f1a2043bc93c5e4e6e4e922e6908a8...      14675812
# 3  0x38c03f0e17422b62f450262e2931a86efa201d3c22e9...      14675760
# 4  0x85ec6a319062f3537420ba60342ff273bbad907bfd9d...      14675332
#
#          date  asset_id                                      seller  \
# 0  2022-04-28      7438  0x2fdcca65899346af3a93a8daa6128bdbcb1ce3b3
# 1  2022-04-28      1397  0xcedf17dfafa947cd0e205fe2a3a183cf2fb3a0bc
# 2  2022-04-28      5226  0x40c839b831c90173dc7fbce49a25274a4688ddd9
# 3  2022-04-28      6498  0x83e7fc69d7c99943afd9122ad0f8bb575e00597c
# 4  2022-04-28      8028  0xe87cc2ea916a7d471976b675d5f72302908e4590
#
#                                         buyer  \
# 0  0xcedf17dfafa947cd0e205fe2a3a183cf2fb3a0bc
# 1  0x93d1f7636f56dd4498c778e212cbe3e2e15bcba9
# 2  0xd30cad3f023888d5a81580fbb80f93102d69e9ef
# 3  0x8dd47e819c53138aa18f8651d797e7969f34d1f1
# 4  0x98bea99727b297f5eca448d1640075f349c08547
#
#                                         maker  \
# 0  0x2fdcca65899346af3a93a8daa6128bdbcb1ce3b3
# 1  0xcedf17dfafa947cd0e205fe2a3a183cf2fb3a0bc
# 2  0x40c839b831c90173dc7fbce49a25274a4688ddd9
# 3  0x83e7fc69d7c99943afd9122ad0f8bb575e00597c
# 4  0xe87cc2ea916a7d471976b675d5f72302908e4590
#
#                                         taker  sale_price_eth  sale_price_usd
# 0  0xcedf17dfafa947cd0e205fe2a3a183cf2fb3a0bc         153.200   442685.528567
# 1  0x93d1f7636f56dd4498c778e212cbe3e2e15bcba9         139.750   403820.513167
# 2  0x00000000a50bb64b4bbeceb18715748dface08af         150.000   433438.833453
# 3  0x8dd47e819c53138aa18f8651d797e7969f34d1f1         145.678   420950.015866
# 4  0x98bea99727b297f5eca448d1640075f349c08547         128.000   369867.804547

# %%
# Import Meta Data
metadata = pd.read_csv("metadata_0xBC4CA0EdA7647A8aB7C2061c2E118A18a936f13D_04302022.csv")
metadata.head()
# Out:
#    asset_id  attribute_count  attribute_count_rarity_score      Hat_attribute  \
# 0         0                6                      1.878640                NaN
# 1         1                5                      3.937008                NaN
# 2         2                5                      3.937008  Sea Captain's Hat
# 3         3                5                      3.937008                NaN
# 4         4                6                      1.878640        Party Hat 2
#
#    Hat_rarity_score Background_attribute  Background_rarity_score  \
# 0          4.432624               Orange                 7.855460
# 1          4.432624               Orange                 7.855460
# 2         32.894737           Aquamarine                 7.898894
# 3          4.432624               Purple                 7.745933
# 4         93.457944                 Blue                 8.051530
#
#   Clothes_attribute  Clothes_rarity_score  Mouth_attribute  \
# 0       Striped Tee             24.271845       Discomfort
# 1    Vietnam Jacket             44.642857             Grin
# 2               NaN              5.302227  Bored Cigarette
# 3     Bone Necklace             49.261084       Tongue Out
# 4  Navy Striped Tee             29.940120        Phoneme L
#
#    Mouth_rarity_score Fur_attribute  Fur_rarity_score Eyes_attribute  \
# 0           48.076923         Robot         37.735849         X Eyes
# 1           14.025245         Robot         37.735849     Blue Beams
# 2           14.084507         Robot         37.735849             3d
# 3           49.504950       Cheetah         24.630542          Bored
# 4           41.493776  Golden Brown         12.853470         Closed
#
#    Eyes_rarity_score Earring_attribute  Earring_rarity_score  \
# 0          41.152263       Silver Hoop             11.337868
# 1         204.081633               NaN              1.423893
# 2          20.533881               NaN              1.423893
# 3           5.834306               NaN              1.423893
# 4          14.084507               NaN              1.423893
#
#    overall_rarity_score
# 0            176.741472
# 1            318.134569
# 2            123.810996
# 3            146.770340
# 4            203.183880

# %%
# Import Transfer Data
transfers = pd.read_csv("transfers_0xBC4CA0EdA7647A8aB7C2061c2E118A18a936f13D_04302022.csv")
transfers.head()
# Out:
#                                     transaction_hash  block_number  \
# 0  0x76b6196f390319fc3c0153bccb82c6e3667298a70d55...      14675899
# 1  0x76b6196f390319fc3c0153bccb82c6e3667298a70d55...      14675899
# 2  0x76b6196f390319fc3c0153bccb82c6e3667298a70d55...      14675899
# 3  0x76b6196f390319fc3c0153bccb82c6e3667298a70d55...      14675899
# 4  0xb235f0321b0b50198399ec7f2bb759ef625f85673b4d...      14675897
#
#          date  asset_id                                from_address  \
# 0  2022-04-28      5037  0xff389e55ee4dd64d82b2b6fefef3f7aa63b218fd
# 1  2022-04-28      5037  0x5f6ac80cdb9e87f3cfa6a90e5140b9a16a361d5c
# 2  2022-04-28      5037  0x3b968d2d299b895a5fcf3bba7a64ad0f566e6f88
# 3  2022-04-28      5037  0x70b97a0da65c15dfb0ffa02aee6fa36e507c2762
# 4  2022-04-28      7438  0x2fdcca65899346af3a93a8daa6128bdbcb1ce3b3
#
#                                    to_address
# 0  0x3b968d2d299b895a5fcf3bba7a64ad0f566e6f88
# 1  0xdbfd76af2157dc15ee4e57f3f942bb45ba84af24
# 2  0x70b97a0da65c15dfb0ffa02aee6fa36e507c2762
# 3  0x5f6ac80cdb9e87f3cfa6a90e5140b9a16a361d5c
# 4  0xcedf17dfafa947cd0e205fe2a3a183cf2fb3a0bc

# %% [markdown]
# # Overpaying For Rarity

# %%
# Join The sales and the meta data
sales_with_meta = sales.join(metadata, on = "asset_id",  lsuffix="_left", rsuffix="_right")

# Take the sales price and divde the rarity to create a $/ rarity score
# The higher the money, and lower rarity = higher score, which means a low value deal
sales_with_meta['$/Rarity'] = sales_with_meta["sale_price_usd"]/sales_with_meta["overall_rarity_score"]

# Create link to OpenSea page
base_url = "https://opensea.io/assets/ethereum/0xbc4ca0eda7647a8ab7c2061c2e118a18a936f13d/"
sales_with_meta['url'] =  base_url + sales_with_meta['asset_id_left'].astype(str)

# Top 10 lowest values
important_columns = ['$/Rarity','asset_id_left',"sale_price_usd","overall_rarity_score", 'date','buyer', 'url']
top_10 = sales_with_meta[important_columns].sort_values(['$/Rarity'],ascending=False)[0:10] 

#Show Table
HTML(top_10.to_html(render_links=True, escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>$/Rarity</th>
#       <th>asset_id_left</th>
#       <th>sale_price_usd</th>
#       <th>overall_rarity_score</th>
#       <th>date</th>
#       <th>buyer</th>
#       <th>url</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1859</th>
#       <td>15975.746473</td>
#       <td>3001</td>
#       <td>1.275556e+06</td>
#       <td>79.843251</td>
#       <td>2022-01-29</td>
#       <td>0xe21dc18513e3e68a52f9fcdacfd56948d43a11c6</td>
#       <td><a href="https://opensea.io/assets/ethereum/0xbc4ca0eda7647a8ab7c2061c2e118a18a936f13d/3001" target="_blank">https://opensea.io/assets/ethereum/0xbc4ca0eda7647a8ab7c2061c2e118a18a936f13d/3001</a></td>
#     </tr>
#     <tr>
#       <th>4903</th>
#       <td>9743.491205</td>
#       <td>2087</td>
#       <td>2.195964e+06</td>
#       <td>225.377541</td>
#       <td>2021-09-30</td>
#       <td>0x79782b0ae9b71cff36bb32b4ef0935fd3c190350</td>
#       <td><a href="https://opensea.io/assets/ethereum/0xbc4ca0eda7647a8ab7c2061c2e118a18a936f13d/2087" target="_blank">https://opensea.io/assets/ethereum/0xbc4ca0eda7647a8ab7c2061c2e118a18a936f13d/2087</a></td>
#     </tr>
#     <tr>
#       <th>1780</th>
#       <td>8917.785784</td>
#       <td>232</td>
#       <td>2.813689e+06</td>
#       <td>315.514270</td>
#       <td>2022-01-30</td>
#       <td>0x69c488bcda156379b6661f08a35db627e5d467dd</td>
#       <td><a href="https://opensea.io/assets/ethereum/0xbc4ca0eda7647a8ab7c2061c2e118a18a936f13d/232" target="_blank">https://opensea.io/assets/ethereum/0xbc4ca0eda7647a8ab7c2061c2e118a18a936f13d/232</a></td>
#     </tr>
#     <tr>
#       <th>250</th>
#       <td>8128.966197</td>
#       <td>3112</td>
#       <td>4.286647e+05</td>
#       <td>52.732988</td>
#       <td>2022-04-19</td>
#       <td>0x79e20edb7c098e799c345e3a5ecff87dbe39a853</td>
#       <td><a href="https://opensea.io/assets/ethereum/0xbc4ca0eda7647a8ab7c2061c2e118a18a936f13d/3112" target="_blank">https://opensea.io/assets/ethereum/0xbc4ca0eda7647a8ab7c2061c2e118a18a936f13d/3112</a></td>
#     </tr>
#     <tr>
#       <th>4623</th>
#       <td>7927.427416</td>
#       <td>5199</td>
#       <td>1.532401e+06</td>
#       <td>193.303725</td>
#       <td>2021-10-14</td>
#       <td>0x020ca66c30bec2c4fe3861a94e4db4a498a35872</td>
#       <td><a href="https://opensea.io/assets/ethereum/0xbc4ca0eda7647a8ab7c2061c2e118a18a936f13d/5199" target="_blank">https://opensea.io/assets/ethereum/0xbc4ca0eda7647a8ab7c2061c2e118a18a936f13d/5199</a></td>
#     </tr>
#     <tr>
#       <th>4558</th>
#       <td>7833.868942</td>
#       <td>8585</td>
#       <td>2.615460e+06</td>
#       <td>333.865658</td>
#       <td>2021-10-19</td>
#       <td>0x86292f24afffe8d4159282980db89e8ef4b92b0a</td>
#       <td><a href="https://opensea.io/assets/ethereum/0xbc4ca0eda7647a8ab7c2061c2e118a18a936f13d/8585" target="_blank">https://opensea.io/assets/ethereum/0xbc4ca0eda7647a8ab7c2061c2e118a18a936f13d/8585</a></td>
#     </tr>
#     <tr>
#       <th>2216</th>
#       <td>7521.567504</td>
#       <td>1734</td>
#       <td>2.477616e+06</td>
#       <td>329.401551</td>
#       <td>2022-01-20</td>
#       <td>0x4f88c947e1c254cf0f56da819e024779fa202787</td>
#       <td><a href="https://opensea.io/assets/ethereum/0xbc4ca0eda7647a8ab7c2061c2e118a18a936f13d/1734" target="_blank">https://opensea.io/assets/ethereum/0xbc4ca0eda7647a8ab7c2061c2e118a18a936f13d/1734</a></td>
#     </tr>
#     <tr>
#       <th>5227</th>
#       <td>6775.470019</td>
#       <td>3928</td>
#       <td>2.139568e+06</td>
#       <td>315.781464</td>
#       <td>2021-09-13</td>
#       <td>0xf50791538e9afc3d3af2953c313f2db96fd993ab</td>
#       <td><a href="https://opensea.io/assets/ethereum/0xbc4ca0eda7647a8ab7c2061c2e118a18a936f13d/3928" target="_blank">https://opensea.io/assets/ethereum/0xbc4ca0eda7647a8ab7c2061c2e118a18a936f13d/3928</a></td>
#     </tr>
#     <tr>
#       <th>193</th>
#       <td>6671.114662</td>
#       <td>6069</td>
#       <td>3.942954e+05</td>
#       <td>59.104880</td>
#       <td>2022-04-20</td>
#       <td>0xa9fe952edd2958ab7dea126c6d8b4413afd3e771</td>
#       <td><a href="https://opensea.io/assets/ethereum/0xbc4ca0eda7647a8ab7c2061c2e118a18a936f13d/6069" target="_blank">https://opensea.io/assets/ethereum/0xbc4ca0eda7647a8ab7c2061c2e118a18a936f13d/6069</a></td>
#     </tr>
#     <tr>
#       <th>147</th>
#       <td>6392.961124</td>
#       <td>3739</td>
#       <td>5.340754e+05</td>
#       <td>83.541154</td>
#       <td>2022-04-23</td>
#       <td>0x6449bbb550f1049236d803f0e43759999b9a2bee</td>
#       <td><a href="https://opensea.io/assets/ethereum/0xbc4ca0eda7647a8ab7c2061c2e118a18a936f13d/3739" target="_blank">https://opensea.io/assets/ethereum/0xbc4ca0eda7647a8ab7c2061c2e118a18a936f13d/3739</a></td>
#     </tr>
#   </tbody>
# </table>
